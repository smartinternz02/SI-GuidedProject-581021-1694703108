# %% [markdown]
# Assignment1

# %% [markdown]
# importing pandas library

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# task1: creating dataframe df with 10 observations and 5 features

# %%
data = {
    'row1': np.random.rand(10),
    'row2': np.random.rand(10),
    'row3': np.random.rand(10),
    'row4': np.random.rand(10),
    'row5': np.random.rand(10)
}
df = pd.DataFrame(data)

# %% [markdown]
# task2: Displaying the DataFrame

# %%
df
# Out:
#        row1      row2      row3      row4      row5
# 0  0.958025  0.240170  0.668990  0.949261  0.229064
# 1  0.223582  0.710712  0.225737  0.191899  0.162246
# 2  0.375460  0.766891  0.693293  0.604310  0.409598
# 3  0.929291  0.360471  0.119488  0.740203  0.781743
# 4  0.554662  0.764356  0.671331  0.996946  0.097961
# 5  0.344939  0.305182  0.699063  0.265476  0.400834
# 6  0.725037  0.199791  0.918014  0.889653  0.380409
# 7  0.795963  0.517456  0.395537  0.079948  0.906152
# 8  0.923703  0.219091  0.853563  0.389140  0.111800
# 9  0.286837  0.843344  0.439087  0.962567  0.711388

# %% [markdown]
# information of the dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   row1    10 non-null     float64
#  1   row2    10 non-null     float64
#  2   row3    10 non-null     float64
#  3   row4    10 non-null     float64
#  4   row5    10 non-null     float64
# dtypes: float64(5)
# memory usage: 528.0 bytes

# %% [markdown]
# to get the shape of the df

# %%
df.shape
# Out:
# (10, 5)

# %% [markdown]
# task3: discriptive statistics

# %%
df.describe()
# Out:
#             row1       row2       row3       row4       row5
# count  10.000000  10.000000  10.000000  10.000000  10.000000
# mean    0.611750   0.492747   0.568410   0.606940   0.419120
# std     0.288934   0.257584   0.262990   0.350787   0.289777
# min     0.223582   0.199791   0.119488   0.079948   0.097961
# 25%     0.352569   0.256423   0.406424   0.296392   0.178951
# 50%     0.639849   0.438964   0.670160   0.672257   0.390622
# 75%     0.891768   0.750945   0.697620   0.934359   0.635941
# max     0.958025   0.843344   0.918014   0.996946   0.906152

# %% [markdown]
# task4: checking the 4th index operation with 'loc' slicing operator

# %%
df.loc[4]
# Out:
# row1    0.554662
# row2    0.764356
# row3    0.671331
# row4    0.996946
# row5    0.097961
# Name: 4, dtype: float64

# %%
df.loc[4:4,'row1':'row5']
# Out:
#        row1      row2      row3      row4      row5
# 4  0.554662  0.764356  0.671331  0.996946  0.097961

# %%
df.iloc[4:5,0:5]
# Out:
#        row1      row2      row3      row4      row5
# 4  0.554662  0.764356  0.671331  0.996946  0.097961

# %% [markdown]
# task5: for finding null values

# %%
df.isnull().any()
# Out:
# row1    False
# row2    False
# row3    False
# row4    False
# row5    False
# dtype: bool

# %% [markdown]
# assignment2

# %% [markdown]
# importing libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# task1: creating dataframe with random values (4 observations and 4 features)

# %%
# Creating a dictionary with random data
data = {
    'feature1': np.random.rand(4),
    'feature2': np.random.rand(4),
    'feature3': np.random.rand(4),
    'feature4': np.random.rand(4)
}

# Creating the DataFrame
df=pd.DataFrame(data)
print(df)
# Out:
#    feature1  feature2  feature3  feature4
# 0  0.915584  0.679999  0.881388  0.981897
# 1  0.804263  0.244990  0.914041  0.724005
# 2  0.527568  0.862682  0.438299  0.455847
# 3  0.574357  0.307716  0.713827  0.448546

# %% [markdown]
# task2: renaming column names to Random Value 1,

# %%
df.rename(columns = {'feature1':'Random Value 1', 'feature2':'Random Value 2',
                              'feature3':'Random Value 3','feature4':'Random Value 4'}, inplace = True)

# %% [markdown]
# task3: discriptive statistics

# %%
df.describe()
# Out:
#        Random Value 1  Random Value 2  Random Value 3  Random Value 4
# count        4.000000        4.000000        4.000000        4.000000
# mean         0.705443        0.523847        0.736889        0.652574
# std          0.185066        0.296461        0.217524        0.254221
# min          0.527568        0.244990        0.438299        0.448546
# 25%          0.562660        0.292035        0.644945        0.454022
# 50%          0.689310        0.493858        0.797608        0.589926
# 75%          0.832094        0.725670        0.889551        0.788478
# max          0.915584        0.862682        0.914041        0.981897

# %% [markdown]
# task 4: for checking null values

# %%
df.isnull().any()
# Out:
# Random Value 1    False
# Random Value 2    False
# Random Value 3    False
# Random Value 4    False
# dtype: bool

# %% [markdown]
# task5: displaying Random value 2 and Random value 3 columns using loc and iloc methods

# %%
df.loc[0:3,"Random Value 2":"Random Value 3"]
# Out:
#    Random Value 2  Random Value 3
# 0        0.679999        0.881388
# 1        0.244990        0.914041
# 2        0.862682        0.438299
# 3        0.307716        0.713827

# %%
df.iloc[:4,1:3]
# Out:
#    Random Value 2  Random Value 3
# 0        0.679999        0.881388
# 1        0.244990        0.914041
# 2        0.862682        0.438299
# 3        0.307716        0.713827
